# %%
# 11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124

# %%
s = '11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124'

# %%
with open('input.txt') as f:
    s= f.read()
# s

# %%
# s.split(',')

# %%
ranges = []
for i in s.split(','):
    ranges.append(i.split('-'))
# ranges

# %%
# now with a few tries:

# %%
for i in range(11,22+1):
    cislo = str(i)
    # print(cislo)
    dlzka = len(cislo)
    if dlzka % 2 == 0:
        # print(cislo,',', cislo[0:dlzka//2], cislo[dlzka//2:])
        if int(cislo[0:dlzka//2]) == int(cislo[dlzka//2:]):
            # print(cislo)
            ...

# %%
for i in range(11,22+1):
    cislo = str(i)
    # print(cislo)
    dlzka = len(cislo)
    if dlzka % 2 == 0:
        # print(cislo,',', cislo[0:dlzka//2], cislo[dlzka//2:])
        left = int(cislo[0:dlzka//2])
        right = int(cislo[dlzka//2:])
        if left == right:
            # print(cislo)
            ...

# %%
result = 0
for my_range in ranges:
    for i in range(int(my_range[0]),int(my_range[1])+1):
        cislo = str(i)
        # print(cislo)
        dlzka = len(cislo)
        if dlzka % 2 == 0:
            # print(cislo,',', cislo[0:dlzka//2], cislo[dlzka//2:])
            left = int(cislo[0:dlzka//2])
            right = int(cislo[dlzka//2:])
            if left == right:
                # print(cislo)
                result += int(cislo)
# print()
print('result:', result)
# Out:
# result: 23039913998

# %%
# done
